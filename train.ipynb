# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization, Conv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from tensorflow.keras import backend as K
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import random
import cv2
import os
import glob

# %%
# Initial parameters
epochs = 100
lr = 1e-3
batch_size = 64
img_dims = (96, 96, 3)
data = []
labels = []

# %%
# Load image files from the dataset
image_files = [f for f in glob.glob(r'gender_dataset_face/**/*', recursive=True) if not os.path.isdir(f)]
random.shuffle(image_files)

# %%
# Converting images to arrays and labeling the categories
for img in image_files:
    image = cv2.imread(img)
    image = cv2.resize(image, (img_dims[0], img_dims[1]))
    image = img_to_array(image)
    data.append(image)

    label = img.split(os.path.sep)[-2]
    label = 1 if label == "woman" else 0
    labels.append(label)

print(f"Loaded {len(data)} images with labels.")
# Out:
# Loaded 11135 images with labels.

# %%
# Preprocessing
data = np.array(data, dtype="float") / 255.0
labels = np.array(labels)

# Split dataset for training and validation
(trainX, testX, trainY, testY) = train_test_split(data, labels, test_size=0.2, random_state=42)

trainY = to_categorical(trainY, num_classes=2)
testY = to_categorical(testY, num_classes=2)

# %%
# Visualize sample images
plt.figure(figsize=(12, 6))
for i in range(9):
    idx = random.randint(0, len(trainX) - 1)
    plt.subplot(3, 3, i + 1)
    plt.imshow(trainX[idx])
    plt.title(f"Label: {'Woman' if np.argmax(trainY[idx]) == 1 else 'Man'}")
    plt.axis('off')
plt.suptitle("Sample Training Images")
plt.tight_layout()
plt.savefig('Images/sample_images.png')
plt.show()

# %%
# Augmenting the dataset
aug = ImageDataGenerator(
    rotation_range=25, 
    width_shift_range=0.1,
    height_shift_range=0.1, 
    shear_range=0.2, 
    zoom_range=0.2,
    horizontal_flip=True, 
    fill_mode="nearest"
)

# Visualize data augmentation
sample_image = trainX[0]
aug_iter = aug.flow(np.expand_dims(sample_image, axis=0), batch_size=1)
plt.figure(figsize=(12, 6))
for i in range(5):
    plt.subplot(1, 5, i + 1)
    aug_image = next(aug_iter)[0]
    plt.imshow(aug_image)
    plt.axis('off')
plt.suptitle("Augmentation Examples")
plt.tight_layout()
plt.savefig('Images/augmented_examples.png')
plt.show()

# %%
# Define the model
def build(width, height, depth, classes):
    model = Sequential()
    inputShape = (height, width, depth)
    chanDim = -1

    if K.image_data_format() == "channels_first":
        inputShape = (depth, height, width)
        chanDim = 1

    model.add(Conv2D(32, (3, 3), padding="same", input_shape=inputShape))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(3, 3)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

    model.add(Conv2D(64, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(128, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))

    model.add(Conv2D(128, (3, 3), padding="same"))
    model.add(Activation("relu"))
    model.add(BatchNormalization(axis=chanDim))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(1024))
    model.add(Activation("relu"))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))

    model.add(Dense(classes))
    model.add(Activation("sigmoid"))

    return model

# Build and compile the model
model = build(width=img_dims[0], height=img_dims[1], depth=img_dims[2], classes=2)

opt = Adam(learning_rate=lr)
model.compile(loss="binary_crossentropy", optimizer=opt, metrics=["accuracy"])
# Out:
# c:\Users\monda\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Train the model
H = model.fit(
    aug.flow(trainX, trainY, batch_size=batch_size),
    validation_data=(testX, testY),
    steps_per_epoch=len(trainX) // batch_size,
    epochs=epochs,
    verbose=1
)
 
# Save the model to disk in .h5 format
model.save('Model/gender_detection.h5')
# Out:
# c:\Users\monda\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 77s 487ms/step - accuracy: 0.6688 - loss: 0.8201 - val_accuracy: 0.5357 - val_loss: 0.7869
# Epoch 2/100
#   1/139 ━━━━━━━━━━━━━━━━━━━━ 1:00 438ms/step - accuracy: 0.6875 - loss: 0.6046
# c:\Users\monda\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\trainers\epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.6875 - loss: 0.6046 - val_accuracy: 0.5424 - val_loss: 0.7607
# Epoch 3/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 61s 440ms/step - accuracy: 0.7377 - loss: 0.5695 - val_accuracy: 0.7059 - val_loss: 0.6182
# Epoch 4/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.7188 - loss: 0.5567 - val_accuracy: 0.7090 - val_loss: 0.6189
# Epoch 5/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 62s 446ms/step - accuracy: 0.7702 - loss: 0.5024 - val_accuracy: 0.6093 - val_loss: 0.6326
# Epoch 6/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.7969 - loss: 0.5096 - val_accuracy: 0.6560 - val_loss: 0.5863
# Epoch 7/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 61s 435ms/step - accuracy: 0.7882 - loss: 0.4721 - val_accuracy: 0.8051 - val_loss: 0.4422
# Epoch 8/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.7344 - loss: 0.5511 - val_accuracy: 0.8002 - val_loss: 0.4427
# Epoch 9/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 60s 428ms/step - accuracy: 0.8077 - loss: 0.4305 - val_accuracy: 0.8505 - val_loss: 0.3331
# Epoch 10/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.7969 - loss: 0.4228 - val_accuracy: 0.8446 - val_loss: 0.3395
# Epoch 11/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 60s 431ms/step - accuracy: 0.8305 - loss: 0.3748 - val_accuracy: 0.8770 - val_loss: 0.2966
# Epoch 12/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8438 - loss: 0.3837 - val_accuracy: 0.8707 - val_loss: 0.3070
# Epoch 13/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 60s 428ms/step - accuracy: 0.8354 - loss: 0.3614 - val_accuracy: 0.8873 - val_loss: 0.2946
# Epoch 14/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8750 - loss: 0.3322 - val_accuracy: 0.8868 - val_loss: 0.3016
# Epoch 15/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 61s 437ms/step - accuracy: 0.8537 - loss: 0.3292 - val_accuracy: 0.8455 - val_loss: 0.4389
# Epoch 16/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9062 - loss: 0.2841 - val_accuracy: 0.8577 - val_loss: 0.4071
# Epoch 17/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 60s 429ms/step - accuracy: 0.8581 - loss: 0.3374 - val_accuracy: 0.8833 - val_loss: 0.2927
# Epoch 18/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8750 - loss: 0.2782 - val_accuracy: 0.8828 - val_loss: 0.2921
# Epoch 19/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 60s 430ms/step - accuracy: 0.8679 - loss: 0.3029 - val_accuracy: 0.9039 - val_loss: 0.2483
# Epoch 20/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8750 - loss: 0.2281 - val_accuracy: 0.9070 - val_loss: 0.2406
# Epoch 21/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 60s 429ms/step - accuracy: 0.8687 - loss: 0.2978 - val_accuracy: 0.8419 - val_loss: 1.2976
# Epoch 22/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9375 - loss: 0.2970 - val_accuracy: 0.8357 - val_loss: 1.0539
# Epoch 23/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 62s 449ms/step - accuracy: 0.8618 - loss: 0.3249 - val_accuracy: 0.8999 - val_loss: 0.2491
# Epoch 24/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8125 - loss: 0.4126 - val_accuracy: 0.9030 - val_loss: 0.2451
# Epoch 25/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 62s 445ms/step - accuracy: 0.8793 - loss: 0.2946 - val_accuracy: 0.8689 - val_loss: 0.3222
# Epoch 26/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8125 - loss: 0.5033 - val_accuracy: 0.8801 - val_loss: 0.3009
# Epoch 27/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 61s 436ms/step - accuracy: 0.8891 - loss: 0.2672 - val_accuracy: 0.8568 - val_loss: 0.3521
# Epoch 28/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8750 - loss: 0.3281 - val_accuracy: 0.8523 - val_loss: 0.3485
# Epoch 29/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 61s 437ms/step - accuracy: 0.8755 - loss: 0.2848 - val_accuracy: 0.9030 - val_loss: 0.2739
# Epoch 30/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8906 - loss: 0.3002 - val_accuracy: 0.9057 - val_loss: 0.2599
# Epoch 31/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 61s 436ms/step - accuracy: 0.8811 - loss: 0.2878 - val_accuracy: 0.9133 - val_loss: 0.2285
# Epoch 32/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9219 - loss: 0.1885 - val_accuracy: 0.9111 - val_loss: 0.2303
# Epoch 33/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 61s 440ms/step - accuracy: 0.8858 - loss: 0.2619 - val_accuracy: 0.8976 - val_loss: 0.2657
# Epoch 34/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.7969 - loss: 0.4531 - val_accuracy: 0.8877 - val_loss: 0.2880
# Epoch 35/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 63s 453ms/step - accuracy: 0.8825 - loss: 0.2737 - val_accuracy: 0.8895 - val_loss: 0.2655
# Epoch 36/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9219 - loss: 0.2085 - val_accuracy: 0.8877 - val_loss: 0.2681
# Epoch 37/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 72s 519ms/step - accuracy: 0.8966 - loss: 0.2454 - val_accuracy: 0.9053 - val_loss: 0.2424
# Epoch 38/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - accuracy: 0.8125 - loss: 0.4052 - val_accuracy: 0.9075 - val_loss: 0.2432
# Epoch 39/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 1961s 14s/step - accuracy: 0.8959 - loss: 0.2527 - val_accuracy: 0.9291 - val_loss: 0.1955
# Epoch 40/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8906 - loss: 0.2127 - val_accuracy: 0.9291 - val_loss: 0.1948
# Epoch 41/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 61s 436ms/step - accuracy: 0.9019 - loss: 0.2412 - val_accuracy: 0.9075 - val_loss: 0.2195
# Epoch 42/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8438 - loss: 0.3647 - val_accuracy: 0.9111 - val_loss: 0.2172
# Epoch 43/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 58s 419ms/step - accuracy: 0.9025 - loss: 0.2378 - val_accuracy: 0.9250 - val_loss: 0.2013
# Epoch 44/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9062 - loss: 0.2429 - val_accuracy: 0.9246 - val_loss: 0.2021
# Epoch 45/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 58s 420ms/step - accuracy: 0.8987 - loss: 0.2391 - val_accuracy: 0.9237 - val_loss: 0.2122
# Epoch 46/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8906 - loss: 0.2883 - val_accuracy: 0.9232 - val_loss: 0.2127
# Epoch 47/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 60s 434ms/step - accuracy: 0.9146 - loss: 0.2115 - val_accuracy: 0.9111 - val_loss: 0.2318
# Epoch 48/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8906 - loss: 0.4148 - val_accuracy: 0.9106 - val_loss: 0.2300
# Epoch 49/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 61s 438ms/step - accuracy: 0.9034 - loss: 0.2254 - val_accuracy: 0.9255 - val_loss: 0.2139
# Epoch 50/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9375 - loss: 0.1744 - val_accuracy: 0.9196 - val_loss: 0.2258
# Epoch 51/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 354s 3s/step - accuracy: 0.9181 - loss: 0.2158 - val_accuracy: 0.9088 - val_loss: 0.2532
# Epoch 52/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9531 - loss: 0.1367 - val_accuracy: 0.9066 - val_loss: 0.2694
# Epoch 53/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 59s 421ms/step - accuracy: 0.9116 - loss: 0.2167 - val_accuracy: 0.9246 - val_loss: 0.1990
# Epoch 54/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8906 - loss: 0.2401 - val_accuracy: 0.9246 - val_loss: 0.2016
# Epoch 55/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 60s 430ms/step - accuracy: 0.9115 - loss: 0.2150 - val_accuracy: 0.9093 - val_loss: 0.2309
# Epoch 56/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8594 - loss: 0.2873 - val_accuracy: 0.9147 - val_loss: 0.2233
# Epoch 57/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 19824s 144s/step - accuracy: 0.9093 - loss: 0.2170 - val_accuracy: 0.9066 - val_loss: 0.2724
# Epoch 58/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9375 - loss: 0.1473 - val_accuracy: 0.9115 - val_loss: 0.2654
# Epoch 59/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 63s 449ms/step - accuracy: 0.9099 - loss: 0.2131 - val_accuracy: 0.9079 - val_loss: 0.2772
# Epoch 60/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8750 - loss: 0.2473 - val_accuracy: 0.9165 - val_loss: 0.2594
# Epoch 61/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 62s 446ms/step - accuracy: 0.9110 - loss: 0.2135 - val_accuracy: 0.9268 - val_loss: 0.2007
# Epoch 62/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9219 - loss: 0.2410 - val_accuracy: 0.9295 - val_loss: 0.2033
# Epoch 63/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 62s 447ms/step - accuracy: 0.9110 - loss: 0.2208 - val_accuracy: 0.9138 - val_loss: 0.2467
# Epoch 64/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9375 - loss: 0.1557 - val_accuracy: 0.9156 - val_loss: 0.2449
# Epoch 65/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 65s 470ms/step - accuracy: 0.9111 - loss: 0.2091 - val_accuracy: 0.8868 - val_loss: 0.2748
# Epoch 66/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.9219 - loss: 0.2202 - val_accuracy: 0.8931 - val_loss: 0.2624
# Epoch 67/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 62s 443ms/step - accuracy: 0.9134 - loss: 0.2004 - val_accuracy: 0.9246 - val_loss: 0.1919
# Epoch 68/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.8906 - loss: 0.2292 - val_accuracy: 0.9273 - val_loss: 0.1938
# Epoch 69/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 64s 462ms/step - accuracy: 0.9211 - loss: 0.2021 - val_accuracy: 0.9035 - val_loss: 0.2584
# Epoch 70/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9531 - loss: 0.1143 - val_accuracy: 0.9062 - val_loss: 0.2532
# Epoch 71/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 64s 463ms/step - accuracy: 0.9245 - loss: 0.1915 - val_accuracy: 0.9237 - val_loss: 0.2066
# Epoch 72/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8906 - loss: 0.4121 - val_accuracy: 0.9241 - val_loss: 0.2056
# Epoch 73/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 65s 464ms/step - accuracy: 0.9220 - loss: 0.1925 - val_accuracy: 0.9322 - val_loss: 0.1928
# Epoch 74/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9375 - loss: 0.1431 - val_accuracy: 0.9335 - val_loss: 0.1921
# Epoch 75/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 64s 462ms/step - accuracy: 0.9150 - loss: 0.2129 - val_accuracy: 0.8604 - val_loss: 0.3090
# Epoch 76/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9062 - loss: 0.1868 - val_accuracy: 0.8756 - val_loss: 0.2864
# Epoch 77/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 63s 454ms/step - accuracy: 0.9163 - loss: 0.2003 - val_accuracy: 0.9070 - val_loss: 0.2384
# Epoch 78/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9062 - loss: 0.1661 - val_accuracy: 0.9017 - val_loss: 0.2431
# Epoch 79/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 172s 1s/step - accuracy: 0.9170 - loss: 0.2043 - val_accuracy: 0.9165 - val_loss: 0.2154
# Epoch 80/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9219 - loss: 0.1751 - val_accuracy: 0.9160 - val_loss: 0.2187
# Epoch 81/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 113s 815ms/step - accuracy: 0.9223 - loss: 0.1970 - val_accuracy: 0.9088 - val_loss: 0.2267
# Epoch 82/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - accuracy: 0.8438 - loss: 0.5009 - val_accuracy: 0.9115 - val_loss: 0.2231
# Epoch 83/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 170s 1s/step - accuracy: 0.9225 - loss: 0.1881 - val_accuracy: 0.9192 - val_loss: 0.2032
# Epoch 84/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.9375 - loss: 0.1280 - val_accuracy: 0.9165 - val_loss: 0.2057
# Epoch 85/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 167s 1s/step - accuracy: 0.9238 - loss: 0.1902 - val_accuracy: 0.9196 - val_loss: 0.2106
# Epoch 86/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 11s 76ms/step - accuracy: 0.8750 - loss: 0.2931 - val_accuracy: 0.9174 - val_loss: 0.2152
# Epoch 87/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 113s 808ms/step - accuracy: 0.9253 - loss: 0.1965 - val_accuracy: 0.9165 - val_loss: 0.2016
# Epoch 88/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.9219 - loss: 0.1589 - val_accuracy: 0.9228 - val_loss: 0.2005
# Epoch 89/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 133s 957ms/step - accuracy: 0.9230 - loss: 0.1885 - val_accuracy: 0.8841 - val_loss: 0.2973
# Epoch 90/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - accuracy: 0.9219 - loss: 0.1645 - val_accuracy: 0.8828 - val_loss: 0.3076
# Epoch 91/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 169s 1s/step - accuracy: 0.9234 - loss: 0.1971 - val_accuracy: 0.9344 - val_loss: 0.1824
# Epoch 92/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 8s 55ms/step - accuracy: 0.9219 - loss: 0.1814 - val_accuracy: 0.9371 - val_loss: 0.1855
# Epoch 93/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 704s 5s/step - accuracy: 0.9271 - loss: 0.1873 - val_accuracy: 0.9313 - val_loss: 0.1917
# Epoch 94/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 0.9844 - loss: 0.0598 - val_accuracy: 0.9300 - val_loss: 0.1913
# Epoch 95/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 131s 937ms/step - accuracy: 0.9261 - loss: 0.1861 - val_accuracy: 0.9246 - val_loss: 0.1985
# Epoch 96/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 0.9062 - loss: 0.1802 - val_accuracy: 0.9237 - val_loss: 0.2007
# Epoch 97/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 148s 1s/step - accuracy: 0.9334 - loss: 0.1762 - val_accuracy: 0.9048 - val_loss: 0.2547
# Epoch 98/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 0.9375 - loss: 0.1943 - val_accuracy: 0.9124 - val_loss: 0.2390
# Epoch 99/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 148s 1s/step - accuracy: 0.9295 - loss: 0.1845 - val_accuracy: 0.9219 - val_loss: 0.2024
# Epoch 100/100
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 8s 52ms/step - accuracy: 0.9219 - loss: 0.2385 - val_accuracy: 0.9259 - val_loss: 0.1982
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Generate predictions
predY = model.predict(testX, batch_size=batch_size)  # Model predictions (probabilities)
predY = np.argmax(predY, axis=1)  # Convert probabilities to class labels
trueY = np.argmax(testY, axis=1)  # True labels (binary 0 or 1)

# Compute confusion matrix
cm = confusion_matrix(trueY, predY)

# Extract TP, FP, FN, TN
tn, fp, fn, tp = cm.ravel()

# Print confusion matrix
print("Confusion Matrix:")
print(cm)
print(f"True Positives (TP): {tp}")
print(f"False Positives (FP): {fp}")
print(f"False Negatives (FN): {fn}")
print(f"True Negatives (TN): {tn}")

# Compute additional metrics
accuracy = accuracy_score(trueY, predY)
precision = tp / (tp + fp) if (tp + fp) > 0 else 0
recall = tp / (tp + fn) if (tp + fn) > 0 else 0
f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1_score:.2f}")

# Classification report for more details
print("\nClassification Report:")
print(classification_report(trueY, predY, target_names=["Man", "Woman"]))
# Out:
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 8s 200ms/step
# Confusion Matrix:
# [[1098   95]
#  [  70  964]]
# True Positives (TP): 964
# False Positives (FP): 95
# False Negatives (FN): 70
# True Negatives (TN): 1098
# Accuracy: 0.93
# Precision: 0.91
# Recall: 0.93
# F1 Score: 0.92
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          Man       0.94      0.92      0.93      1193
#        Woman       0.91      0.93      0.92      1034
#
#     accuracy                           0.93      2227
#    macro avg       0.93      0.93      0.93      2227
# weighted avg       0.93      0.93      0.93      2227

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\monda\appdata\local\programs\python\python312\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\monda\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\monda\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\monda\appdata\local\programs\python\python312\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\monda\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\monda\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\monda\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\monda\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\monda\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\monda\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\monda\appdata\local\programs\python\python312\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\monda\appdata\roaming\python\python312\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\monda\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\monda\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\monda\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Man", "Woman"], yticklabels=["Man", "Woman"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()

# %%
# Display predictions on test images
plt.figure(figsize=(12, 6))
for i in range(9):
    idx = random.randint(0, len(testX) - 1)
    plt.subplot(3, 3, i + 1)
    plt.imshow(testX[idx])
    pred_label = 'Woman' if predY[idx] == 1 else 'Man'
    true_label = 'Woman' if trueY[idx] == 1 else 'Man'
    plt.title(f"True: {true_label}\nPred: {pred_label}")
    plt.axis('off')
plt.tight_layout()
plt.savefig('Images/test_predictions.png')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Ensure that the number of epochs matches the length of the history data
epochs = 30  # Set this to the number of epochs you actually trained
history = H  # Assuming H is your training history object

# Make sure history has values for the epochs
loss = history.history['loss']
val_loss = history.history['val_loss']
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# Adjust number of epochs based on the length of the history data
N = min(len(loss), len(val_loss), len(accuracy), len(val_accuracy))

# Plot training & validation loss and accuracy
plt.style.use("ggplot")
plt.figure(figsize=(12, 6))

# Plot Loss
plt.subplot(1, 2, 1)
plt.plot(np.arange(0, N), loss[:N], label='train_loss')
plt.plot(np.arange(0, N), val_loss[:N], label='val_loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(np.arange(0, N), accuracy[:N], label='train_accuracy')
plt.plot(np.arange(0, N), val_accuracy[:N], label='val_accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Save the plot to disk
plt.tight_layout()
plt.savefig('Images/plot.png')

# Show the plot
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Predict probabilities for the test set
pred_prob = model.predict(testX, batch_size=batch_size)

# Compute FPR, TPR, and thresholds for the positive class
fpr, tpr, thresholds = roc_curve(testY[:, 1], pred_prob[:, 1])

# Compute the AUC (Area Under the Curve)
roc_auc = auc(fpr, tpr)

# Plot the ROC Curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='red', linestyle='--')  # Diagonal line for random guessing
plt.title('ROC Curve for Gender Detection Model')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.grid()
plt.savefig('Images/roc_curve.png')  # Save the plot
plt.show()
# Out:
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step
